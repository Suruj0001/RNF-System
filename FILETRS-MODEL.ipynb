# %%
import cv2
from skimage import io , restoration 
from matplotlib import  pyplot  as plt
from skimage.filters import roberts , sobel , scharr , prewitt , try_all_threshold , threshold_otsu , threshold_triangle , threshold_minimum
import numpy as np
from skimage.feature import canny
from skimage.filters.rank import entropy
from skimage.morphology import disk

# %%
image = io.imread(r"C:\Users\suruj\PYTHON-IMAGE-PROCESSING\demo\pht\horse.jfif" , as_gray=False) 
image = cv2.resize(image , (800,400))
# b,g,r = cv2.split(image)
# image = cv2.merge((r,g,b))
plt.imshow(image)
cv2.imshow("horse",image)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imwrite(r"C:\Users\suruj\PYTHON-IMAGE-PROCESSING\demo\pht\nft2.jpg" , image)
# Out:
# True

# %%
entropy_img = io.imread(r"C:\Users\suruj\PYTHON-IMAGE-PROCESSING\demo\pht\anitique.jfif" ,  as_gray=True) 
entropy_img = cv2.resize(entropy_img, (800,500))
entropy_img = entropy(entropy_img, disk(3))
plt.imshow(entropy_img)
# cv2.imshow("entropy",entropy_img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# C:\Users\suruj\AppData\Local\Temp\ipykernel_17036\3206119724.py:3: UserWarning: Possible precision loss converting image of type float64 to uint8 as required by rank filters. Convert manually using skimage.util.img_as_ubyte to silence this warning.
#   entropy_img = entropy(entropy_img, disk(3))

# %%
fig , ax = try_all_threshold(entropy_img , figsize = (10,8) , verbose=True) 
#In this article, we will learn about VERBOSE flag of the re package and how to use it.
#This flag allows you to write regular expressions that look nicer and are more readable 
#by allowing you to visually separate logical sections of the pattern and add comments.
# Out:
# skimage.filters.thresholding.threshold_isodata
# skimage.filters.thresholding.threshold_li
# skimage.filters.thresholding.threshold_mean
# skimage.filters.thresholding.threshold_minimum
# skimage.filters.thresholding.threshold_otsu
# skimage.filters.thresholding.threshold_triangle
# skimage.filters.thresholding.threshold_yen

# %%
thresh = threshold_triangle(entropy_img)
binary = entropy_img <= thresh
plt.imshow(binary)

# %%
# entropy_img = io.imread(r"C:\Users\suruj\PYTHON-IMAGE-PROCESSING\demo\pht\horse.jfif" ,  as_gray=True) 
# thresh = threshold_minimum(entropy_img)
# binary = entropy_img <= thresh
# plt.imshow(binary)
